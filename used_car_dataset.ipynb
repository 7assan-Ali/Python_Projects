# %%
import numpy as np 
import pandas as pd
import matplotlib.pylab as plt 

df=pd.read_csv('used_car_dataset.csv')

df = df.drop('AdditionInfo', axis=1)
df = df.drop('Age', axis=1)

mean_km_driven = data['kmDriven'].mean()

df['kmDriven'] = df['kmDriven'].str.replace('km', '', regex=False).str.replace(',', '').astype(float)
df = df.replace(0, mean_km_driven)


mean_km_driven = data['kmDriven'].mean()

df['AskPrice'] = df['AskPrice'].str.replace('₹ ', '', regex=False).str.replace(',', '').astype(float)
df = df.replace(0, mean_km_driven)



df['AskPrice'] = df['AskPrice'].fillna(mean_km_driven)
df=df.drop_duplicates()

df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8781 entries, 0 to 9581
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         8781 non-null   object
#  1   model         8781 non-null   object
#  2   Year          8781 non-null   int64
#  3   kmDriven      8735 non-null   float64
#  4   Transmission  8781 non-null   object
#  5   Owner         8781 non-null   object
#  6   FuelType      8781 non-null   object
#  7   PostedDate    8781 non-null   object
#  8   AskPrice      8781 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 686.0+ KB
#               Brand      model  Year  kmDriven Transmission   Owner  \
# 0             Honda       City  2001   98000.0       Manual  second
# 1            Toyota     Innova  2009  190000.0       Manual  second
# 2        Volkswagen  VentoTest  2010   77246.0       Manual   first
# ...

# %%
print(df.info())
#47 kmDriven is null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8781 entries, 0 to 9581
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         8781 non-null   object
#  1   model         8781 non-null   object
#  2   Year          8781 non-null   int64
#  3   kmDriven      8735 non-null   float64
#  4   Transmission  8781 non-null   object
#  5   Owner         8781 non-null   object
#  6   FuelType      8781 non-null   object
#  7   PostedDate    8781 non-null   object
#  8   AskPrice      8781 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 686.0+ KB
# None

# %%
#df.to_csv("cleaned_dataset.csv", index=False)

# %%
df
# Out:
#               Brand      model  Year  kmDriven Transmission   Owner  \
# 0             Honda       City  2001   98000.0       Manual  second
# 1            Toyota     Innova  2009  190000.0       Manual  second
# 2        Volkswagen  VentoTest  2010   77246.0       Manual   first
# 3     Maruti Suzuki      Swift  2017   83500.0       Manual  second
# 4     Maruti Suzuki     Baleno  2019   45000.0    Automatic   first
# ...             ...        ...   ...       ...          ...     ...
# 9577          Skoda    Octavia  2014  105904.0    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020   55000.0       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   92000.0       Manual   first
# 9580        Hyundai      Verna  2019   72000.0    Automatic   first
# 9581        Hyundai    New i20  2021   83228.0       Manual  second
#
#         FuelType PostedDate   AskPrice
# 0         Petrol     Nov-24   195000.0
# 1         Diesel     Jul-24   375000.0
# ...

# %%
df
# Out:
#               Brand      model  Year  kmDriven Transmission   Owner  \
# 0             Honda       City  2001   98000.0       Manual  second
# 1            Toyota     Innova  2009  190000.0       Manual  second
# 2        Volkswagen  VentoTest  2010   77246.0       Manual   first
# 3     Maruti Suzuki      Swift  2017   83500.0       Manual  second
# 4     Maruti Suzuki     Baleno  2019   45000.0    Automatic   first
# ...             ...        ...   ...       ...          ...     ...
# 9577          Skoda    Octavia  2014  105904.0    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020   55000.0       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   92000.0       Manual   first
# 9580        Hyundai      Verna  2019   72000.0    Automatic   first
# 9581        Hyundai    New i20  2021   83228.0       Manual  second
#
#         FuelType PostedDate   AskPrice
# 0         Petrol     Nov-24   195000.0
# 1         Diesel     Jul-24   375000.0
# ...

# %%
group_py_owner1=df.groupby('Owner')['AskPrice'].sum()
group_py_owner1
# Out:
# Owner
# first     5.751463e+09
# second    3.385953e+09
# Name: AskPrice, dtype: float64

# %%
group_py_owner1.plot(kind='bar',ylabel='AskPrice',xlabel='Owner',title='Owner and AskPrice')
# Out:
# <Axes: title={'center': 'Owner and AskPrice'}, xlabel='Owner', ylabel='AskPrice'>

# %%
group_py_Transmission=df.groupby('Transmission')['AskPrice'].sum()
group_py_Transmission
# Out:
# Transmission
# Automatic    6.553054e+09
# Manual       2.584362e+09
# Name: AskPrice, dtype: float64

# %%
group_py_Transmission.plot(kind='bar',ylabel='AskPrice',xlabel='Transmission',title='Owner and Transmission')
# Out:
# <Axes: title={'center': 'Owner and Transmission'}, xlabel='Transmission', ylabel='AskPrice'>

# %%
group_py_Year=df.groupby('Year')['AskPrice'].sum()
group_py_Year
# Out:
# Year
# 1986    1.200000e+05
# 1990    2.500000e+05
# 1994    6.050000e+05
# 1996    4.490000e+05
# 1997    2.500000e+05
# 1998    1.430000e+05
# 1999    3.865000e+06
# 2000    2.260000e+05
# 2001    8.910000e+05
# 2002    9.830000e+05
# 2003    1.450000e+06
# 2004    1.962000e+06
# 2005    4.239998e+06
# 2006    6.365999e+06
# 2007    1.280334e+07
# 2008    1.756918e+07
# 2009    4.073170e+07
# 2010    8.449999e+07
# 2011    1.464827e+08
# 2012    2.058505e+08
# 2013    2.781082e+08
# 2014    4.037556e+08
# 2015    5.805416e+08
# 2016    7.119217e+08
# 2017    9.719187e+08
# 2018    9.584335e+08
# 2019    1.035975e+09
# 2020    7.712018e+08
# 2021    8.679353e+08
# 2022    9.018778e+08
# 2023    7.745267e+08
# 2024    3.514828e+08
# Name: AskPrice, dtype: float64

# %%
group_py_Year.plot(kind='bar',ylabel='AskPrice',xlabel='Year',title='Owner and Transmission')
# Out:
# <Axes: title={'center': 'Owner and Transmission'}, xlabel='Year', ylabel='AskPrice'>

# %%
Petrol = df.query('FuelType == "Petrol"')
Petrol
# Out:
#               Brand                model  Year  kmDriven Transmission   Owner  \
# 0             Honda                 City  2001   98000.0       Manual  second
# 4     Maruti Suzuki               Baleno  2019   45000.0    Automatic   first
# 8     Maruti Suzuki  maruti-suzuki-dzire  2020   33759.0       Manual  second
# 9              Ford             Ecosport  2017   69713.0       Manual  second
# 10    Maruti Suzuki             Alto-K10  2018   70000.0    Automatic   first
# ...             ...                  ...   ...       ...          ...     ...
# 9572            Kia                Sonet  2023   12000.0       Manual   first
# 9573         Toyota        Corolla Altis  2017   82000.0       Manual  second
# 9576        Porsche              Cayenne  2023    7700.0    Automatic   first
# 9580        Hyundai                Verna  2019   72000.0    Automatic   first
# 9581        Hyundai              New i20  2021   83228.0       Manual  second
#
# ...

# %%
Petrol_cars = Petrol ['Brand'].value_counts()
Petrol_cars.plot(kind='bar',  
                 xlabel='Brand',  
                 ylabel='Count',  
                 title='Petrol Cars',  
                 grid=True,
                 legend=False)
# Out:
# <Axes: title={'center': 'Petrol Cars'}, xlabel='Brand', ylabel='Count'>

# %%
Diesel = df.query('FuelType == "Diesel"')
Diesel
# Out:
#               Brand      model  Year  kmDriven Transmission   Owner FuelType  \
# 1            Toyota     Innova  2009  190000.0       Manual  second   Diesel
# 2        Volkswagen  VentoTest  2010   77246.0       Manual   first   Diesel
# 3     Maruti Suzuki      Swift  2017   83500.0       Manual  second   Diesel
# 5               BMW         X3  2014   83000.0    Automatic   first   Diesel
# 6            Toyota     Innova  2014  168000.0       Manual  second   Diesel
# ...             ...        ...   ...       ...          ...     ...      ...
# 9568         Toyota   Fortuner  2018   86000.0    Automatic   first   Diesel
# 9574           Audi         Q5  2012  160000.0    Automatic  second   Diesel
# 9575     Volkswagen  VentoTest  2018   75000.0    Automatic   first   Diesel
# 9577          Skoda    Octavia  2014  105904.0    Automatic  second   Diesel
# 9579  Maruti Suzuki       Ritz  2013   92000.0       Manual   first   Diesel
#
#      PostedDate   AskPrice
# ...

# %%
Diesel_cars = Diesel ['Brand'].value_counts()
Diesel_cars .plot(   kind='bar',
    xlabel='Brand',
    ylabel='Count',
    title='Diesel cars',
    grid=True,
    legend=False)
# Out:
# <Axes: title={'center': 'Diesel cars'}, xlabel='Brand', ylabel='Count'>

# %%
Hybrid_CNG = df.query('FuelType == "Hybrid/CNG"')
Hybrid_CNG
# Out:
#               Brand        model  Year  kmDriven Transmission   Owner  \
# 3825        Hyundai         Aura  2020   29000.0       Manual   first
# 3828  Maruti Suzuki  Swift-Dzire  2020   98000.0       Manual  second
# 3830  Maruti Suzuki     Alto-K10  2015   72000.0       Manual   first
# 3834  Maruti Suzuki      Wagon-R  2013   80000.0       Manual   first
# 3838        Hyundai   i20 Active  2016   64000.0       Manual  second
# ...             ...          ...   ...       ...          ...     ...
# 9561  Maruti Suzuki      Wagon-R  2019   65000.0       Manual   first
# 9563  Maruti Suzuki         Eeco  2015       NaN       Manual  second
# 9564  Maruti Suzuki  Wagon-R-1-0  2019      35.0    Automatic  second
# 9570        Hyundai    Grand i10  2019   57000.0    Automatic  second
# 9578  Maruti Suzuki     Alto-800  2020   55000.0       Manual   first
#
#         FuelType PostedDate  AskPrice
# 3825  Hybrid/CNG     Nov-24  650000.0
# 3828  Hybrid/CNG     Nov-24  590000.0
# ...

# %%
Hybrid_CNG_cars = Hybrid_CNG ['Brand'].value_counts()
Hybrid_CNG_cars .plot(   kind='bar',
    xlabel='Hybrid/CNG ',
    ylabel='Count',
    title='Hybrid_CNG Cars',
    grid=True,
    legend=False)
# Out:
# <Axes: title={'center': 'Hybrid_CNG Cars'}, xlabel='Hybrid/CNG ', ylabel='Count'>

# %%
Manual = df.query('Transmission == "Manual"')
Manual
# Out:
#               Brand          model  Year  kmDriven Transmission   Owner  \
# 0             Honda           City  2001   98000.0       Manual  second
# 1            Toyota         Innova  2009  190000.0       Manual  second
# 2        Volkswagen      VentoTest  2010   77246.0       Manual   first
# 3     Maruti Suzuki          Swift  2017   83500.0       Manual  second
# 6            Toyota         Innova  2014  168000.0       Manual  second
# ...             ...            ...   ...       ...          ...     ...
# 9572            Kia          Sonet  2023   12000.0       Manual   first
# 9573         Toyota  Corolla Altis  2017   82000.0       Manual  second
# 9578  Maruti Suzuki       Alto-800  2020   55000.0       Manual   first
# 9579  Maruti Suzuki           Ritz  2013   92000.0       Manual   first
# 9581        Hyundai        New i20  2021   83228.0       Manual  second
#
#         FuelType PostedDate   AskPrice
# 0         Petrol     Nov-24   195000.0
# ...

# %%
Manual_cars = Manual ['Brand'].value_counts()
Manual_cars .plot(   kind='bar',
    xlabel='Manual Cars',
    ylabel='Count',
    title='Manual',
    grid=True,
    legend=False)
# Out:
# <Axes: title={'center': 'Manual'}, xlabel='Manual Cars', ylabel='Count'>

# %%
Automatic = df.query('Transmission == "Automatic"')
Automatic
# Out:
#               Brand      model  Year  kmDriven Transmission   Owner FuelType  \
# 4     Maruti Suzuki     Baleno  2019   45000.0    Automatic   first   Petrol
# 5               BMW         X3  2014   83000.0    Automatic   first   Diesel
# 7               BMW   5 Series  2019   25000.0    Automatic  second   Diesel
# 10    Maruti Suzuki   Alto-K10  2018   70000.0    Automatic   first   Petrol
# 11              Kia   Carnival  2021   25000.0    Automatic   first   Diesel
# ...             ...        ...   ...       ...          ...     ...      ...
# 9574           Audi         Q5  2012  160000.0    Automatic  second   Diesel
# 9575     Volkswagen  VentoTest  2018   75000.0    Automatic   first   Diesel
# 9576        Porsche    Cayenne  2023    7700.0    Automatic   first   Petrol
# 9577          Skoda    Octavia  2014  105904.0    Automatic  second   Diesel
# 9580        Hyundai      Verna  2019   72000.0    Automatic   first   Petrol
#
#      PostedDate    AskPrice
# ...

# %%
Automatic_cars = Automatic ['Brand'].value_counts()
Automatic_cars .plot(   kind='bar',
    xlabel='Automatic Cars',
    ylabel='Count',
    title='dkfahfjkag',
    grid=True,
    legend=False)
# Out:
# <Axes: title={'center': 'dkfahfjkag'}, xlabel='Automatic Cars', ylabel='Count'>

# %%
Honda = data.query('Brand == "Honda"')
Honda
# Out:
#       Brand    model  Year  kmDriven Transmission   Owner    FuelType  \
# 0     Honda     City  2001   98000.0       Manual  second      Petrol
# 22    Honda     City  2010   99000.0       Manual   first      Petrol
# 52    Honda     City  2010   79000.0       Manual  second      Petrol
# 53    Honda      BRV  2016  103001.0       Manual  second      Diesel
# 73    Honda     City  2016   93000.0    Automatic  second      Petrol
# ...     ...      ...   ...       ...          ...     ...         ...
# 9524  Honda  City ZX  2008  119000.0    Automatic  second  Hybrid/CNG
# 9544  Honda     City  2015   80000.0    Automatic  second      Petrol
# 9547  Honda     Jazz  2016   78000.0       Manual  second      Diesel
# 9552  Honda     City  2022   11000.0    Automatic   first      Petrol
# 9566  Honda     WR-V  2021   68000.0       Manual   first      Diesel
#
#      PostedDate     AskPrice
# 0        Nov-24   ₹ 1,95,000
# 22       Nov-24   ₹ 2,95,000
# 52       Nov-24   ₹ 2,90,000
# ...

# %%
transmission_counts = Honda['Transmission'].value_counts()
transmission_counts .plot(kind='pie',
        y='Transmission' ,legend=False,
        autopct='%1.2f%%' ,title='Transmission Types in Honda Cars')
# Out:
# <Axes: title={'center': 'Transmission Types in Honda Cars'}, ylabel='count'>
